# %%
def square(x):
    return x ** 2
# Use the map function to apply the square function to each element in a list of integers from 1 to 10
numbers = list(range(1, 11))
squaredNumbers = list(map(square, numbers))
# Print the result
print("List of squared numbers:", squaredNumbers)
# Out:
# List of squared numbers: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
